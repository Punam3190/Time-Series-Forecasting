# %%
pip install pandas-profiling
# Out:
# ...
#
# ...

# %%
import pandas as pd
from pandas_profiling import ProfileReport
# Out:
# C:\Users\Punam\AppData\Local\Temp\ipykernel_19428\3034448462.py:2: DeprecationWarning: `import pandas_profiling` is going to be deprecated by April 1st. Please use `import ydata_profiling` instead.
#   from pandas_profiling import ProfileReport

# %%
df = pd.read_csv('Dataset Cement.csv')

# %%
df
# Out:
#       Month  Demand_MT  Sales_MT  Unit_price  Total_price  \
# 0   2015-01       5.91      5.71         390      2226.90
# 1   2015-02       5.42      5.41         385      2082.85
# 2   2015-03       4.82      4.75         380      1805.00
# 3   2015-04       4.68      4.55         395      1797.25
# 4   2015-05       4.69      4.56         400      1824.00
# ..      ...        ...       ...         ...          ...
# 91  2022-08       7.42      7.35         371      2726.34
# 92  2022-09       8.23      8.14         387      3149.20
# 93  2022-10       8.33      8.26         372      3073.71
# 94  2022-11       9.33      9.22         388      3577.36
# 95  2022-12       9.75      9.73         391      3804.43
#
#     Transportation Cost  Housing Interest Rate  GDP Construction
# 0                467.65                    7.5            214180
# 1                416.57                    8.1            214179
# 2                397.10                    7.9            214181
# ...

# %%
design_report = ProfileReport(df)

# %%
design_report.to_file(output_file='report.html')
# Out:
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
