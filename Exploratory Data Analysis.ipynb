# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import scipy as sp
import warnings
import datetime
warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
df = pd.read_csv("Dataset Cement.csv")

# %%
df
# Out:
#       Month  Demand_MT  Sales_MT  Unit_price  Total_price  \
# 0   2015-01       5.91      5.71         390      2226.90
# 1   2015-02       5.42      5.41         385      2082.85
# 2   2015-03       4.82      4.75         380      1805.00
# 3   2015-04       4.68      4.55         395      1797.25
# 4   2015-05       4.69      4.56         400      1824.00
# ..      ...        ...       ...         ...          ...
# 91  2022-08       7.42      7.35         371      2726.34
# 92  2022-09       8.23      8.14         387      3149.20
# 93  2022-10       8.33      8.26         372      3073.71
# 94  2022-11       9.33      9.22         388      3577.36
# 95  2022-12       9.75      9.73         391      3804.43
#
#     Transportation Cost  Housing Interest Rate  GDP Construction
# 0                467.65                    7.5            214180
# 1                416.57                    8.1            214179
# 2                397.10                    7.9            214181
# ...

# %%
df.head()
# Out:
#      Month  Demand_MT  Sales_MT  Unit_price  Total_price  Transportation Cost  \
# 0  2015-01       5.91      5.71         390      2226.90               467.65
# 1  2015-02       5.42      5.41         385      2082.85               416.57
# 2  2015-03       4.82      4.75         380      1805.00               397.10
# 3  2015-04       4.68      4.55         395      1797.25               377.42
# 4  2015-05       4.69      4.56         400      1824.00               401.28
#
#    Housing Interest Rate  GDP Construction
# 0                    7.5            214180
# 1                    8.1            214179
# 2                    7.9            214181
# 3                    8.5            218253
# 4                    7.6            218252

# %%
df.describe()
# Out:
#        Demand_MT   Sales_MT  Unit_price  Total_price  Transportation Cost  \
# count  96.000000  96.000000   96.000000    96.000000            96.000000
# mean    6.673958   6.614896  381.500000  2519.165625           520.184896
# std     1.655105   1.655579   13.978178   623.151860           134.313613
# min     4.050000   4.030000  350.000000  1484.000000           281.960000
# 25%     5.187500   5.110000  371.750000  1940.882500           402.480000
# 50%     6.755000   6.725000  385.000000  2487.445000           513.160000
# 75%     7.920000   7.902500  391.250000  3022.197500           625.122500
# max     9.940000   9.910000  405.000000  3808.710000           799.830000
#
#        Housing Interest Rate  GDP Construction
# count              96.000000         96.000000
# mean                8.041146     246530.562500
# std                 1.048859      37422.588174
# min                 6.300000     131436.000000
# 25%                 7.300000     225098.250000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Month                  96 non-null     object
#  1   Demand_MT              96 non-null     float64
#  2   Sales_MT               96 non-null     float64
#  3   Unit_price             96 non-null     int64
#  4   Total_price            96 non-null     float64
#  5   Transportation Cost    96 non-null     float64
#  6   Housing Interest Rate  96 non-null     float64
#  7   GDP Construction       96 non-null     int64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 6.1+ KB

# %%
df.value_counts()
# Out:
# Month    Demand_MT  Sales_MT  Unit_price  Total_price  Transportation Cost  Housing Interest Rate  GDP Construction
# 2015-01  5.91       5.71      390         2226.90      467.65               7.5                    214180              1
# 2015-02  5.42       5.41      385         2082.85      416.57               8.1                    214179              1
# 2020-11  7.03       7.02      398         2796.91      643.29               7.3                    274751              1
# 2020-10  6.95       6.92      390         2699.49      539.90               8.9                    274752              1
# 2020-09  6.85       6.84      367         2510.28      502.06               6.6                    224898              1
#                                                                                                                       ..
# 2017-06  5.42       5.41      395         2136.95      427.39               8.9                    235402              1
# ...

# %%
df.shape
# Out:
# (96, 8)

# %%
df.dtypes
# Out:
# Month                     object
# Demand_MT                float64
# Sales_MT                 float64
# Unit_price                 int64
# Total_price              float64
# Transportation Cost      float64
# Housing Interest Rate    float64
# GDP Construction           int64
# dtype: object

# %%
df.columns
# Out:
# Index(['Month', 'Demand_MT', 'Sales_MT', 'Unit_price', 'Total_price',
#        'Transportation Cost', 'Housing Interest Rate', 'GDP Construction'],
#       dtype='object')

# %% [markdown]
# # Checking Null Value

# %%
df.isnull().sum()
# Out:
# Month                    0
# Demand_MT                0
# Sales_MT                 0
# Unit_price               0
# Total_price              0
# Transportation Cost      0
# Housing Interest Rate    0
# GDP Construction         0
# dtype: int64

# %%
df.isnull().any()
# Out:
# Month                    False
# Demand_MT                False
# Sales_MT                 False
# Unit_price               False
# Total_price              False
# Transportation Cost      False
# Housing Interest Rate    False
# GDP Construction         False
# dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.hist(figsize=(20,14))
plt.show()

# %%
df.corr()
# Out:
#                        Demand_MT  Sales_MT  Unit_price  Total_price  \
# Demand_MT               1.000000  0.997591   -0.181340     0.984879
# Sales_MT                0.997591  1.000000   -0.182937     0.987780
# Unit_price             -0.181340 -0.182937    1.000000    -0.031997
# Total_price             0.984879  0.987780   -0.031997     1.000000
# Transportation Cost     0.956683  0.959542   -0.010274     0.973973
# Housing Interest Rate   0.105249  0.109267    0.044389     0.119479
# GDP Construction        0.598301  0.596823   -0.130840     0.585315
#
#                        Transportation Cost  Housing Interest Rate  \
# Demand_MT                         0.956683               0.105249
# Sales_MT                          0.959542               0.109267
# Unit_price                       -0.010274               0.044389
# Total_price                       0.973973               0.119479
# Transportation Cost               1.000000               0.103507
# ...

# %%
 plt.figure(figsize = (12,10))

sns.heatmap(df.corr(), annot =True)
# Out:
# <AxesSubplot: >

# %%
df.columns
# Out:
# Index(['Month', 'Demand_MT', 'Sales_MT', 'Unit_price', 'Total_price',
#        'Transportation Cost', 'Housing Interest Rate', 'GDP Construction'],
#       dtype='object')

# %%
plt.figure(figsize=(14,10))
sns.set_style(style='whitegrid')
plt.subplot(2,3,1)
sns.boxplot(x='Demand_MT',data=df)
plt.subplot(2,3,2)
sns.boxplot(x='Sales_MT',data=df)
plt.subplot(2,3,3)
sns.boxplot(x='Unit_price',data=df)
plt.subplot(2,3,4)
sns.boxplot(x='Total_price',data=df)
plt.subplot(2,3,5)
sns.boxplot(x='Transportation Cost',data=df)
plt.subplot(2,3,6)
sns.boxplot(x='GDP Construction',data=df)
# Out:
# <AxesSubplot: xlabel='GDP Construction'>

# %%
plt.figure(figsize=(14,10))
sns.set_style(style='whitegrid')
plt.subplot(2,3,1)
sns.distplot(df['Demand_MT'])
plt.subplot(2,3,2)
sns.distplot(df['Sales_MT'])
plt.subplot(2,3,3)
sns.distplot(df['Unit_price'])
plt.subplot(2,3,4)
sns.distplot(df['Total_price'])
plt.subplot(2,3,5)
sns.distplot(df['Transportation Cost'])
plt.subplot(2,3,6)
sns.distplot(df['GDP Construction'])
# Out:
# <AxesSubplot: xlabel='GDP Construction', ylabel='Density'>

# %% [markdown]
# ##As we can see GDP Construction has outliers .
# ##IQR Based Filtering(to remove outliers)

# %%
###Form a box-plot for the skewed feature

sns.boxplot(df['GDP Construction'])
# Out:
# <AxesSubplot: xlabel='GDP Construction'>

# %%
###Finding the IQR

Q1 = df['GDP Construction'].quantile(0.25)
Q3 = df['GDP Construction'].quantile(0.75)

# %%
IQR = Q3 -Q1

# %%
###Finding the upper and lower limits

upper_limit = percentile75 + 1.5 * IQR
lower_limit = percentile25 - 1.5 * IQR

# %%
 ###Finding outliers

df[df['GDP Construction'] > upper_limit]
df[df['GDP Construction'] < lower_limit]
# Out:
#       Month  Demand_MT  Sales_MT  Unit_price  Total_price  \
# 63  2020-04       6.95      6.94         398      2759.34
# 64  2020-05       6.98      6.97         355      2475.05
# 65  2020-06       7.92      7.90         385      3044.66
#
#     Transportation Cost  Housing Interest Rate  GDP Construction
# 63               524.28                   6.65            131437
# 64               470.26                   9.70            131436
# 65               624.16                  10.70            131438

# %%
###Trimming outliers

new_df = df[df['GDP Construction'] < upper_limit]
new_df.shape
# Out:
# (90, 8)

# %%
###Compare the plots after trimming

plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.distplot(df['GDP Construction'])
plt.subplot(2,2,2)
sns.boxplot(df['GDP Construction'])
plt.subplot(2,2,3)
sns.distplot(new_df['GDP Construction'])
plt.subplot(2,2,4)
sns.boxplot(new_df['GDP Construction'])
plt.show()

# %%
###Capping

new_df_cap = df.copy()
new_df_cap['GDP Construction'] = np.where(
    new_df_cap['GDP Construction'] > upper_limit,
    upper_limit,
    np.where(
        new_df_cap['GDP Construction'] <lower_limit,
        lower_limit,
        new_df_cap['GDP Construction']))

# %%
###Compare the plots after capping

plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.distplot(df['GDP Construction'])
plt.subplot(2,2,2)
sns.boxplot(df['GDP Construction'])
plt.subplot(2,2,3)
sns.distplot(new_df_cap['GDP Construction'])
plt.subplot(2,2,4)
sns.boxplot(new_df_cap['GDP Construction'])
plt.show()

# %%
sns.pairplot(data=df)

# %%
sns.jointplot(x='Demand_MT', y= 'Sales_MT', data=df)
